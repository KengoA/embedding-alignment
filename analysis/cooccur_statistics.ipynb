# %%
import numpy as np
import pandas as pd

# %%
img_path = '../cooccur/openimages/data/preprocessed/open-images.csv'
# txt_path = '../glove/data/cooccur/cooccur_text_name.csv'

# %%
df_img = pd.read_csv(img_path)
df_txt = pd.read_csv(txt_path)

# %%
len(set(df_img['ImageID']))
# Out:
# 1892542
